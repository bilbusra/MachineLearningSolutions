# %%
# !pip install PyDrive
# Out:
# ...
#     100% |████████████████████████████████| 993kB 18.0MB/s
# ...
# done
#   Stored in directory: /root/.cache/pip/wheels/fa/d2/9a/d3b6b506c2da98289e5d417215ce34b696db856643bad779f4
# Successfully built PyDrive
# ...

# %%
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
import pandas as pd
import io
import datetime
import numpy as np
from matplotlib import pyplot

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
download = drive.CreateFile({'id': '1aiCPFSDPubbwwod30ckWJi8lIiMaU5dU'})
download.GetContentFile('yoochoose-clicks.dat')

# %%
download2 = drive.CreateFile({'id': '1px5GBDDiYe4HAbjBIWANIxqzRTHxEQrg'})
download2.GetContentFile('yoochoose-buys.dat')

# %%
read_clicks = pd.read_csv('yoochoose-clicks.dat', low_memory = False)

# %%
print(read_clicks.head())
# Out:
#    1  2014-04-07T10:51:09.277Z  214536502  0
# 0  1  2014-04-07T10:54:09.868Z  214536500  0
# 1  1  2014-04-07T10:54:46.998Z  214536506  0
# 2  1  2014-04-07T10:57:00.306Z  214577561  0
# 3  2  2014-04-07T13:56:37.614Z  214662742  0
# 4  2  2014-04-07T13:57:19.373Z  214662742  0

# %%
print(list(read_clicks.columns.values))
# Out:
# ['1', '2014-04-07T10:51:09.277Z', '214536502', '0']

# %%
read_clicks.columns = ['session_id', 'timestamp', 'item_id', 'category']

# %%
print(read_clicks.head())
print("click dataset contains " + str(len(read_clicks))  )
# Out:
#    session_id                 timestamp    item_id category
# 0           1  2014-04-07T10:54:09.868Z  214536500        0
# 1           1  2014-04-07T10:54:46.998Z  214536506        0
# 2           1  2014-04-07T10:57:00.306Z  214577561        0
# 3           2  2014-04-07T13:56:37.614Z  214662742        0
# 4           2  2014-04-07T13:57:19.373Z  214662742        0
# click dataset contains 33003943

# %%
read_clicks[read_clicks.session_id == 11 ]
# Out:
#     session_id                 timestamp    item_id category
# 23          11  2014-04-03T10:44:35.672Z  214821275        0
# 24          11  2014-04-03T10:45:01.674Z  214821275        0
# 25          11  2014-04-03T10:45:29.873Z  214821371        0
# 26          11  2014-04-03T10:46:12.162Z  214821371        0
# 27          11  2014-04-03T10:46:57.355Z  214821371        0
# 28          11  2014-04-03T10:53:22.572Z  214717089        0
# 29          11  2014-04-03T10:53:49.875Z  214563337        0
# 30          11  2014-04-03T10:55:19.267Z  214706462        0
# 31          11  2014-04-03T10:55:47.327Z  214717436        0
# 32          11  2014-04-03T10:56:30.520Z  214743335        0
# 33          11  2014-04-03T10:57:19.331Z  214826837        0
# 34          11  2014-04-03T10:57:39.433Z  214819762        0

# %%
read_buys[read_buys.session_id == 21]
# Out:
#     session_id                 timestamp    item_id  price  quantity
# 22          21  2014-04-07T09:24:18.307Z  214548744   3141         1
# 23          21  2014-04-07T09:24:18.360Z  214838503  18745         1

# %%
read_buys = pd.read_csv('yoochoose-buys.dat', low_memory = False)

# %%
read_buys.columns = ['session_id', 'timestamp', 'item_id', 'price', 'quantity']

# %%
buy_dict = dict(zip(read_buys.session_id, read_buys.item_id))

# %%
buy_dict.get(21)
# Out:
# 214838503

# %%
def fstDidBuy(row):
  return (buys_dict.get(row) and
# Out:
# None

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-abd470402e8a> in <module>()
# ----> 1 read_buys = read_buys.group_by('session_id')
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'

# %%
#read_hebele = pd.DataFrame()

# %%
#read_helebe = read_clicks.copy(deep=True)

# %%
#print(read_hebele.head())

# %%
#read_hebele[~read_hebele.index.isin(read_buys.index)]

# %%
#linesClicks = read_clicks.iloc[:,0:5].values

# %%
#buysClicks = read_buys.iloc[:,0:5].values

# %%
list_session_clicks = read_clicks.iloc[:,0].values

# %%
list_session_buys = read_buys.iloc[:,0].values

# %%
non_bought_session = set(list_session_clicks).symmetric_difference(set(list_session_buys))

# %%
#read_clicks["bought_sessions"] = read_clicks["session"].isin(read_buys["session"]) and read_b[""]

# %%
prop = len(non_bought_session) / len(list_session_buys)

# %%
print(prop)

# %%
import random

# %%
#df_elements.head()

# %%
#make proportion by 1.5 for getting avoid of class imbalance
newSize = int(len(list_session_buys) * 1.5)
print(newSize)

# %%
#a = templist + random.sample(non_bought, newSize)

# %%
print(len(read_clicks))

# %%
len(read_buys)

# %%
clickNoBuy = read_clicks[read_clicks.session_id.isin(non_bought_session)]

# %%
df_elements = clickNoBuy.sample(n=newSize)

# %%
print(len(clickNoBuy))

# %%
print(read_buys[read_buys.session_id == 1])

# %%
clickNoBuy.head()

# %%
#df_elements.head()

# %%
print(df_elements.head())

# %%
df_elements.columns = ['session_id', 'timestamp', 'item_id', 'category']

# %%
df_elements = df_elements.append(read_clicks[read_clicks.session_id.isin(read_buys.session_id)])

# %%
len(read_clicks['session_id'])

# %%
#df_elements.drop(['item id'])

# %%
len(df_elements)

# %%
df_elements = df_elements.sort_values(by=['session_id', 'item_id'])

# %%
df_elements.head()

# %%
read_buys = read_buys.sort_values(by=['session_id', 'item_id'])

# %%
#df_elements["didBuy"] = df_elements["session_id"].isin(read_buys["session_id"]).astype(int)

# %%
def checkNum(row):
  z = int(str(row[0]) + str(row[2]))
  return z

# %%
df_elements['checkNo'] = df_elements.apply(lambda row: checkNum(row), axis=1)

# %%
read_buys['checkNo'] = read_buys.apply(lambda row: checkNum(row), axis=1)

# %%
df_elements["didBuy"] = df_elements["checkNo"].isin(read_buys["checkNo"]).astype(int)

# %%
len(df_elements[df_elements.didBuy == 0])

# %%
len(df_elements[df_elements.didBuy == 1])

# %%
2934449/1809678

# %%
df_elements.head()

# %%
df_elements = df_elements.drop(['checkNo'], axis = 1)

# %%
df_elements.to_csv('clickAzEnSon.csv')

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from google.colab import files
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
file3 = drive.CreateFile({'parents':[{u'id': '1-i5vSPVbOW_nDb7ulGh4eMjXQfKkPYNW'}]})
file3.SetContentFile("clickAzEnSon.csv")
file3.Upload()

# %%
def label_year (row):
  dtm = datetime.datetime.strptime(str(row[1]), "%Y-%m-%dT%H:%M:%S.%fZ")
  return dtm.year

# %%
def label_month (row):
  dtm = datetime.datetime.strptime(str(row[1]), "%Y-%m-%dT%H:%M:%S.%fZ")
  return dtm.month

# %%
def label_day (row):
  dtm = datetime.datetime.strptime(str(row[1]), "%Y-%m-%dT%H:%M:%S.%fZ")
  return dtm.day

# %%
def label_hour (row):
  dtm = datetime.datetime.strptime(str(row[1]), "%Y-%m-%dT%H:%M:%S.%fZ")
  return dtm.hour

# %%
#df_elements['year'] = df_elements.apply(lambda row : label_year(row), axis =1 )

# %%
#df_elements.head()

# %%
#df_elements['day'] = df_elements.apply(lambda row : label_day(row), axis =1 )

# %%
#df_elements.head()

# %%
#df_elements['hour'] = df_elements.apply(lambda row : label_hour(row), axis =1 )

# %%
#intr = set(df_elements['session id']).intersection(set(read_buys['session id']))
#print(intr)

# %%
"""df_elements_new = df_elements[df_elements.session_id.isin(intr)]
#gapminder_2002 = gapminder[gapminder.year == 2002]
print(df_elements_new)
"""

# %%
#print(len(intr))

# %%
#df_elements.merge(read_buys)

# %%
df_elements.to_csv('out.csv', sep=',' )
#df.to_csv('out.csv', sep=',')

# %%
#print(df_elements.head())

# %%
#from sklearn.preprocessing import MultiLabelBinarizer

# %%
#mlb = MultiLabelBinarizer()

# %%
#feature_column_name = 'features'

# %%
#feature_matrix = mlb.fit_transform(df_elements['category'])

# %%
#print(feature_matrix)

# %%
#np.vstack((feature_matrix, np.array(df_elements['hour'])))
#np.c_[ feature_matrix, np.array(df_elements['hour']) ]
#np.c_[ feature_matrix, np.array(df_elements['day']) ]

# %%
#np.c_[ feature_matrix, np.array(df_elements['day']) ]

# %%
#print(feature_matrix.shape)

# %%
#print(np.array(df_elements['hour']).shape)
